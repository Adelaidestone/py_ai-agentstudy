# %%
##调用deepseek官网的deepseek模型
##sk-78c78c385b664a17a45bfc304636e432
import os
from langchain_deepseek import ChatDeepSeek
from dotenv import load_dotenv

load_dotenv(override=True)  # 加载 .env 文件中的环境变量


DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")
llm_deepseek=ChatDeepSeek(
    model="deepseek-v4-flash",  # 模型名称
    api_key=DEEPSEEK_API_KEY,
    api_base=DEEPSEEK_BASE_URL  # DeepSeek API 的基础 URL
)

response = llm_deepseek.invoke("请用中文介绍一下LangChain的作用")
print(response)
# Out:
# content='LangChain 是一个开源框架，专门用于简化基于大型语言模型（LLM）的应用程序开发。它的核心作用包括：\n\n1. **模块化组件**：将 LLM 与提示管理、记忆存储、数据连接、工具调用等能力封装成可组合的模块，开发者可以像搭积木一样构建复杂的工作流。\n2. **链式调用（Chain）**：支持将多个 LLM 调用或外部操作（如 API 请求、数据库查询）串联起来，形成自动化流程，例如“先检索文档再生成回答”。\n3. **智能代理（Agent）**：允许 LLM 根据用户意图自主决定调用哪些工具（如计算器、搜索引擎），实现动态推理和决策。\n4. **数据上下文增强**：通过文档加载器、文本分割器、向量数据库等组件，将外部私有数据注入模型，解决 LLM 知识过时或缺乏内部数据的问题（RAG 模式）。\n5. **多模型与多平台支持**：统一接口兼容 OpenAI、Anthropic、Hugging Face 等数十种模型提供商，方便切换和测试。\n6. **会话记忆管理**：内置多种记忆机制（缓冲区、摘要、实体存储），使聊天机器人能记住历史对话。\n\n**典型应用场景**：智能问答机器人、文档分析助手、代码生成工具、自主 Agent 系统（如自动化客服、研究助理）等。简单说，LangChain 就是为了让开发者更高效、更灵活地搭建 LLM 应用，而不必重复处理底层集成细节。' additional_kwargs={'refusal': None, 'reasoning_content': '我们被问到：“请用中文介绍一下LangChain的作用”。LangChain是一个流行的开源框架，用于构建基于大型语言模型（LLM）的应用。需要介绍它的核心作用，比如简化LLM应用的开发，提供模块化组件（模型、提示、记忆、链、代理等），支持多种模型提供商，以及常见用例（问答、聊天机器人、文档分析等）。回答应清晰、简洁、中文。'} response_metadata={'token_usage': {'completion_tokens': 412, 'prompt_tokens': 11, 'total_tokens': 423, 'completion_tokens_details': {'accepted_prediction_tokens
# ...

# %%
##调用deepseek官网的deepseek模型
##sk-78c78c385b664a17a45bfc304636e432
import os
from langchain_deepseek import ChatDeepSeek
from dotenv import load_dotenv

load_dotenv(override=True)  # 加载 .env 文件中的环境变量


DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")
llm_deepseek=ChatDeepSeek(
    model="deepseek-v4-flash",  # 模型名称
    #api_key=DEEPSEEK_API_KEY,
   #api_base=DEEPSEEK_BASE_URL  # DeepSeek API 的基础 URL
)

response = llm_deepseek.invoke("请用中文介绍一下LangChain的作用")
print(response)
# Out:
# content='LangChain 是一个开源框架，专门用于构建基于大型语言模型（LLM）的应用程序。它的核心作用是**简化开发流程**，让开发者能够更高效地将 LLM 与外部数据源、工具、API 以及复杂的逻辑流程结合起来。\n\n具体来说，LangChain 的主要作用体现在以下几个方面：\n\n1. **数据连接与增强**  \n   允许 LLM 访问外部数据（如数据库、文档、网页、PDF 等），通过检索增强生成（RAG）技术，使模型能够基于最新、最相关的私有知识回答问题，解决 LLM 知识过时和缺乏领域知识的局限。\n\n2. **链式调用（Chains）**  \n   将多个 LLM 调用或其他处理步骤（如提示模板、数据处理、工具调用）组合成一个有序的流水线，实现复杂的多步推理或任务，例如“先总结文档，再翻译成英文，最后提取关键点”。\n\n3. **提示管理与优化**  \n   提供提示模板（Prompt Templates）机制，支持动态插入变量、示例和上下文，方便复用和优化提示词，降低调试成本。\n\n4. **记忆（Memory）**  \n   维护对话历史或上下文状态，使 LLM 能记住之前的交互内容，适用于聊天机器人、多轮对话等需要连贯性的场景。\n\n5. **智能代理（Agents）**  \n   赋予 LLM 自主决策能力，让它能根据任务动态选择并调用外部工具（如搜索引擎、计算器、API、数据库查询），自动分解问题并执行多步操作。\n\n6. **评估与监控**  \n   提供工具对 LLM 的输出进行评测，追踪调用过程和结果，便于调试和生产环境监控。\n\n**总结**：LangChain 的作用相当于 LLM 应用的“操作系统”——它屏蔽了底层与 LLM 交互、数据集成、逻辑编排的复杂性，让开发者可以快速搭建从简单问答到复杂推理、自动化工作流的各类 AI 应用。' additional_kwargs={'refusal': None, 'reasoning_content': '我们被问到："请用中文介绍一下LangChain的作用"。这是一个直接的问题。需要解释LangChain是什么，它的主要作用。LangChain是一个用于开发由语言模型驱动的应用程序的框架。需要详细说明其核心功能：连接LLM与外部数据源，构建
# ...

# %%
##兼容写法

from langchain_openai import ChatOpenAI


load_dotenv(override=True)
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

llm_openai=ChatOpenAI(
    model="deepseek-v4-flash",  # 模型名称
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL  # DeepSeek API 的基础 URL
)

response = llm_openai.invoke("你是小红帽吗")
print(response)
# Out:
# content='哈哈，我不是小红帽哦～我是你的AI助手，一个没有童话角色、但可以陪你聊天、解答问题的智能程序！如果你需要听小红帽的故事，或者想聊聊其他话题，我随时都在～ 😄' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 112, 'prompt_tokens': 8, 'total_tokens': 120, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 65, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 8}, 'model_provider': 'openai', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'a3f04a5d-136a-4c2a-bd6c-b79ab978bf79', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f4705-4877-7411-9948-f527d4cad8bb-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 112, 'total_tokens': 120, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}}

# %%
##使用chat 1.x的方式
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os


load_dotenv(override=True)
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

llm_openai=init_chat_model(
    model="deepseek-v4-flash",  # 模型名称
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL  # DeepSeek API 的基础 URL
)

response = llm_openai.invoke("你是小红帽吗")
print(response)
# Out:
# content='哈哈，我不是小红帽哦！我是你的AI助手，一个由代码和算法组成的小伙伴～小红帽是童话里戴着红帽子去探望奶奶的小姑娘，而我是虚拟世界里的“百事通”，能和你聊天、解答问题，还能帮忙查资料、写故事呢！😄 有什么需要帮忙的，随时告诉我吧～' additional_kwargs={'refusal': None, 'reasoning_content': '咦？用户问我是小红帽还是AI助手。这个问题有点童话感，可能是在玩梗或者想测试我的身份识别能力。需要明确说明自己是AI，避免误会。可以顺便延伸一下小红帽故事的经典情节，增加互动趣味性。再主动提供帮助选项，把话题引向实际需求。嗯，平衡清晰说明和轻松语气。'} response_metadata={'token_usage': {'completion_tokens': 146, 'prompt_tokens': 8, 'total_tokens': 154, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 74, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 8}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '1eeba001-e420-4ac9-b09b-f15bb752fecb', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f4a04-60ef-7292-891b-87253bbc7df8-0' tool_calls=[] invalid_tool_cal
# ...

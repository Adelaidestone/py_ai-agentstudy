# %%
##使用chat 1.x的方式
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os


load_dotenv(override=True)
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

model=init_chat_model(
    model="deepseek-v4-flash",  # 模型名称
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL  # DeepSeek API 的基础 URL
)

for chunk in model.stream("帮我解释一下谁是梅西"):
    print(chunk.text, end="", flush=True)
# Out:
# 当然。梅西是世界上最著名的足球运动员之一，被广泛认为是足球史上最伟大的球员（经常与C罗、马拉多纳、贝利等人并列讨论）。
#
# 简单来说，他是**阿根廷的职业足球运动员**，目前效力于**美国职业足球大联盟（MLS）的迈阿密国际队**，司职**前锋**或**攻击型中场**。
#
# 以下是关于他的几个核心要点，帮助你快速了解为什么他如此出名：
#
# 1.  **无与伦比的足球天赋：** 梅西的控球、盘带、传球和射门能力都达到了极高水平。他个子不高（1.69米），但重心低、步频极快，能在狭小空间内以不可思议的方式过人并得分。球迷常说他“把足球粘在脚上”。
#
# 2.  **辉煌的俱乐部生涯（主要是在巴塞罗那）：**
#     -   他在**巴塞罗那俱乐部**效力了17个赛季（2000-2021年青年队和一线队），成为俱乐部历史上最伟大的球员。
#     -   他赢得了**10次西甲冠军**、**4次欧冠冠军**、**7次国王杯冠军**等一系列荣誉。
#     -   他保持着巴塞罗那队史进球第一（672球）、助攻第一等多个纪录。
#
# 3.  **个人荣誉无数：**
#     -   他赢得了**8次金球奖**（世界最佳足球运动员奖项），这个纪录至今无人能破。
#     -   他多次获得欧洲金靴奖（欧洲最佳射手）和世界足球先生称号。
#
# 4.  **国家队的“救赎”与巅峰：**
#     -   在很长一段时间里，梅西在阿根廷国家队的表现引发争议，曾连续三次在决赛失利（2014年世界杯亚军、2015和2016年美洲杯亚军），承受了巨大的心理压力。
#     -   然而，在**2021年**，他终于带领阿根廷队赢得**美洲杯**冠军，打破了国家队无冠的魔咒。
#     -   在**2022年卡塔尔世界杯**上，他带领阿根廷队击败法国队，赢得**世界杯冠军**，完成了足球运动员的最高梦想。他在整个赛事中表现出色，获得世界杯金球奖（赛事最佳球员）。这一刻被视为他职业生涯的完美句点。
#
# 5.  **技术特点总结：** 他速度奇快、变向灵活、射门精准（擅长挑射和低平球），传球视野开阔，是一位集顶级射手、组织者和领导者于一体的球员。
#
# **简单一句话总结：**
#
# 梅西是一位技术天赋登峰造极、在俱乐部获得无数荣誉、最终带领国家队圆梦世界杯的阿根廷足球传奇，堪称**当代球王**。
#
# 如果你对他有什么具体方面（比如某场比赛、某个纪录、或者和C罗的比较）感兴趣，可以继续问我。

# %% [markdown]
# # 2.批量调用（batch）

# %%
##使用chat 1.x的方式
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os


load_dotenv(override=True)
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

model=init_chat_model(
    model="deepseek-v4-flash",  # 模型名称
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,  # DeepSeek API 的基础 URL
    

)

messages = [
    "梅西和c罗谁强",
    "阿根廷和法国队你觉得谁会获得2026世界杯冠军",
    "谁是姆巴佩",
]

responses = model.batch(messages)

for response in responses:
    print(response)
# Out:
# content='这是一个足球界的经典问题，也是无数球迷讨论的焦点。直接给出“谁更强”的结论是不公平的，因为他们都是历史级别的足球巨星，但**风格和特质截然不同**。\n\n可以这样理解：**梅西代表了足球的艺术性和极致的个人天赋，而C罗则代表了永不停歇的进取心、身体极限和胜利意志。**\n\n下面从几个关键维度来比较，你可以根据自己的偏好来判断谁更符合你心中“更强”的定义。\n\n### 1. 天赋与技术（梅西胜）\n\n这几乎是公认的。梅西的天赋是历史级别的，甚至可以说是空前绝后的。\n\n-   **盘带与过人：** 梅西的步频、球感和重心控制能力是历史最强之一。他能在极小的空间内连续过人，就像球粘在脚上一样。他多次上演“过五关斩六将”的神作，比如对赫塔菲的连过五人。\n-   **传球与视野：** 梅西的传球视野极其开阔，他不仅是得分手，更是顶级的进攻组织者。他的直塞球和长传转移非常致命，职业生涯助攻数也位列历史第一。\n-   **射门精度：** 虽然C罗的射门力量更足，但梅西的射门更多是巧射，尤其是他的“贴地斩”和挑射，精准度极高。他的逆足（右脚）水平也高于C罗的逆足（左脚）。\n\n**小结：** 在纯粹的天赋、球感和技术能力上，梅西是独一无二的。\n\n### 2. 身体、力量与适应性（C罗胜）\n\nC罗的强项在于他超凡的身体素质和适应能力。\n\n-   **身体条件：** 年轻时C罗以速度和花哨过人闻名，后来转型为力量型前锋。他的弹跳力、滞空能力、头球技术和核心力量都属于历史顶级。他能像“直升机”一样起跳，头球攻门。\n-   **射门能力：** C罗的射门力量极大，无论远射、凌空抽射还是任意球，势大力沉。他职业生涯后期的“远射炮”和“电梯球”是他的标志。\n-   **精神属性：** 这是C罗最被称道的地方。他拥有近乎偏执的自律、对胜利的极度渴望和强大的心理素质。在绝境中，他往往能站出来，逆转战局（例如2019年欧冠对马竞的帽子戏法）。\n\n**小结：** 在身体素质、精神意志力和从边锋转型为超级射手的适应能力上，C罗是现象级的。\n\n### 3. 荣誉与数据（不相上下）\n\n两人在俱乐部和国家队都取得了惊人的成就：\n\n-   **梅西：**\n    -   8次金球奖（历史第一）\n    -   4次欧冠冠军\n    -   10次西甲冠军\n    -   2022年世界杯冠军（填补了最大的空白）\n    -   2次美洲杯冠军\n    -   职业生涯进球数超过800，助攻数超过350（历史第一）。\n\n-   **C罗：**\n    -   5次金球奖\n    -   5次欧冠冠军（历史第一，包括欧冠三连冠）\n    -   3次英超冠军，2次西甲冠军，2次意甲冠军（在三大主流联赛都获得过MVP）\n    -   2016年欧洲杯冠军（葡萄牙历史首冠）\n    -   职业生涯总进球数超过900（历史第一），欧冠历史最佳射手（140球）。\n\n**小结：** 从团队荣誉看，梅西有世界杯，C罗有欧洲杯；从个人奖项看，梅西金球奖更多；从数据看，C罗是历史总进球王，梅西是历史助攻王。两者在荣誉和数据上是同级别的巅峰。\n\n### 4. 关键比赛的统治力（各有千秋）\n\n-   **梅西：** 在巅峰期的巴萨，梅西在“国家德比”中表现出色，也是欧冠淘汰赛的杀手。但在阿根廷国家队初期，他一度在决赛中表现不佳（2014年世界杯、2015-2016年美洲杯）。不过，2022年世界杯是他团队领导力的完美证明。\n-   **C罗：** 被称为“大场面先生”，在欧冠淘汰赛和决赛中经常有决定性发挥（如2018年对尤文的倒钩，2019年对马竞的帽子戏法）。他的精神属性和在关键比赛中的表现很少让人失望。\n\n### 结论\n\n**如果你是“技术流”和“艺术家”的推崇者，你会认为梅西更强。** 他代表了足球最纯粹、最优雅的美感，用天赋和想象力征服了全世界。\n\n**如果你是“硬汉”和“斗士”的推崇者，你会认为C罗更强。** 他代表了人类战胜极限的意志，用后天的努力和自律达到了与天赋齐平的巅峰。\n\n**总结来说：** 梅西的天赋和技术是历史第一，C罗的身体、意志和进球效率是历史第一。他们处在足球世界的两个极端，一个代表了天赋的极致，一个代表了努力的极致。他们共同定义了这个伟大的足球时代。\n\n因此，**不存在谁强谁弱，只有你更喜欢谁。**' additional_kwargs={'refusal': None, 'reasoning_content': '嗯，用户问的是“梅西和C罗谁强”，这是一个非常经典且容易引发争论的足球话题。用户可能是在寻求一个客观、全面的比较分析，而不是简单的主观结论。这个问题没有绝对的标准答案，取决于如何定义“强”——是个人技术、团队贡献、进球数据、还是历史地位。\n\n我需要避免给出武断的结论，而是从多个维度展开比较，比如巅峰期的技术特点、职业生涯数据、关键荣誉、对球队的影响等。同时要强调结论因人而异，最终给出一个平衡的、尊重不同观点的总结。\n\n想到了可以从这几个方面来组织回答：先指出这是一个经典的对比问题，没有唯一答案。然后分别从技术风格、数据荣誉、巅峰表现、领导力等方面进行客观罗列。最后总结，指出他们的伟大之处不同，孰强孰弱取决于个人偏好。确保语气平和、专业，避免引发争吵。'} response_metadata={'token_usage': {'completion_tokens': 1278, 'prompt_tokens': 10, 'total_tokens': 1288, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 182, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 10}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'c64a26b2-9348-4381-ae78-44dff78ab3b7', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f4a97-0be6-7340-b30e-5b141bc785a8-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 10, 'output_tokens': 1278, 'total_tokens': 1288, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 182}}
# content='这是一个非常有趣的假设性问题！虽然2026年世界杯还有两年多的时间，但根据两队的现状和趋势，我们可以做一个合理的推演。\n\n**简单来说：目前看，法国队的纸面实力和年龄结构更占优势，但阿根廷的冠军底蕴和团队凝聚力是不可忽视的变量。**\n\n下面是详细分析：\n\n### 为什么法国队更被看好？\n\n1.  **恐怖的阵容深度与年龄结构**：法国队拥有当今足坛最豪华的“人才库”。核心球员如**姆巴佩**（2026年时28岁，正值巅峰）、**卡马文加**、**琼阿梅尼**、**萨利巴**等都在黄金年龄。即使格列兹曼、吉鲁等老将可能淡出，新一代的攻击手（如埃梅里、穆阿尼）已经崭露头角。\n2.  **身体+技术的完美结合**：法国队的打法兼具力量、速度和现代足球的高强度对抗。在北美举办的世界杯（气候、长途飞行）中，这种身体优势会更加明显。\n3.  **大赛基因**：自2018年以来，法国队两届世界杯（一冠一亚）、一届欧洲杯（亚军），证明他们拥有在顶级舞台稳定输出的能力。\n\n### 为什么阿根廷仍有竞争力？\n\n1.  **世界冠军的底气与体系成熟**：斯卡洛尼的教练团队已经将阿根廷打造成一支极度团结、战术纪律严明的球队。这种“赢家心态”和团队化学反应，是任何纸面优势都无法替代的。\n2.  **“梅西变量”与年轻化**：虽然梅西到2026年将年满39岁，但如果他决定参赛（目前他的表态很开放），哪怕只在关键场次发挥20-30分钟的作用，他的存在本身就是对对手的巨大威慑。同时，阿根廷也在加速年轻化，**恩佐·费尔南德斯**、**阿尔瓦雷斯**、**劳塔罗**等球员届时都在巅峰期。\n3.  **南美预选赛的磨砺**：南美区预选赛的残酷性，往往能让阿根廷在大赛前保持极高的竞技状态和战术韧性。\n\n### 需要警惕的变数\n\n-   **核心球员状态**：法国队能否解决“内讧传统”？阿根廷能否在没有梅西时依然高效？这些都是未知数。\n-   **伤病与运气**：2026年世界杯赛程更长（48队，需打7场），伤病概率大增。核心球员的健康将直接决定上限。\n-   **对手的崛起**：巴西、英格兰、德国（本土作战？）、西班牙等队同样虎视眈眈。法国和阿根廷未必能顺利在决赛相遇。\n\n### 结论与建议\n\n**从纯竞技概率角度看，法国队是更领先的热门。** 他们的球员年龄结构、个人能力和大赛经验，构成了一套非常成熟的冠军拼图。**阿根廷则更像“韧性王者”**，依靠团队和信念弥补天赋差距。\n\n**所以，如果非要二选一，我倾向于选择法国队。** 但有一个前提：如果他们能保持团结，且德尚教练能顺利过渡到新的战术体系。\n\n**最后，一个更聪明的回答是：** 在世界杯开赛前一年，看两队的预选赛表现和关键球员的状态，会更有参考价值。现在预测，只是享受足球的乐趣罢了。😊\n\n**您更看好谁呢？是相信阿根廷的卫冕底蕴，还是法国的新王当立？**' additional_kwargs={'refusal': None, 'reasoning_content': '嗯，用户问的是2026年世界杯冠军预测，具体是阿根廷和法国队之间选一个。这个问题挺有意思的，但2026年世界杯还有两年多，变数太大了。用户可能是个足球迷，想听听分析或者单纯的预测。\n\n我得先理清楚现状。阿根廷是2022年卡塔尔世界杯冠军，梅西还在，但2026年他已经39岁了，状态和角色肯定会有变化。法国队连续两届世界杯进决赛，2018年夺冠，2022年亚军，年轻球员像姆巴佩、登贝莱、琼阿梅尼这些都在巅峰期，阵容厚度和年龄结构看起来更好。\n\n不过，足球预测不能只看纸面实力。阿根廷的团队体系很成熟，斯卡洛尼的战术执行力强，而且南美球队在北美举办的世界杯会不会有优势？法国队的问题在于更衣室管理和内讧传统，2022年决赛前就有一些不和谐声音。\n\n从概率上讲，法国队阵容更年轻、更全面，姆巴佩到2026年才27岁，正是黄金年龄。阿根廷过度依赖梅西，如果他状态下滑或者伤病，影响会很大。但阿根廷的冠军底蕴和凝聚力也不容小觑。\n\n我觉得不能直接给出绝对答案，因为这种预测没有标准答案。更合适的做法是分析双方的优势和风险，然后给出一个倾向性的判断，同时提醒用户不确定性。最终结论可以偏法国队，但要说明依据。'} response_metadata={'token_usage': {'completion_tokens': 1027, 'prompt_tokens': 15, 'total_tokens': 1042, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 298, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 15}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'ee379c36-6b69-437b-ac4b-783a205988c4', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f4a97-0bea-74c3-866b-f24c7d456256-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 15, 'output_tokens': 1027, 'total_tokens': 1042, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 298}}
# content='姆巴佩（Kylian Mbappé）全名基利安·姆巴佩·洛坦（Kylian Mbappé Lottin），1998年12月20日出生于法国邦迪，是当今足坛最受瞩目的超级巨星之一。以下是他最核心的信息：\n\n- **位置与特点**：司职前锋，以**惊人的速度**、出色的盘带和门前嗅觉著称，常被球迷称为“忍者神龟”（因其外貌和跑动风格）。\n- **职业生涯亮点**：\n  - **俱乐部**：2017年从摩纳哥转会至巴黎圣日耳曼（PSG），成为队史最佳射手之一。2024年夏天**自由转会加盟皇家马德里**，实现了少年时的“儿皇梦”。\n  - **国家队**：2018年随法国队赢得**世界杯冠军**，并在决赛中进球；2022年世界杯决赛上演**帽子戏法**，虽屈居亚军，但以8球荣膺赛事金靴。\n- **荣誉**：多次获得法甲冠军、法国杯冠军，以及法国足球先生、法甲最佳射手、最佳球员等个人奖项。\n\n**最新动态**：2024年夏天他正式加盟皇马，身穿9号球衣（后续也可能接替传奇号码），与维尼修斯、贝林厄姆等组成新一代“银河战舰”锋线。\n\n总的来说，姆巴佩被视为**梅西与C罗时代之后，最有可能统治世界足坛的球员之一**。如果你还想了解他的转会细节、本赛季表现或与哈兰德的“双骄”对比，可以继续问我～' additional_kwargs={'refusal': None, 'reasoning_content': '用户问的是“谁是姆巴佩”，看起来是想了解这位足球运动员的基本信息。姆巴佩现在知名度很高，尤其是刚转会皇马，相关动态很多。考虑到用户可能只是想要一个简洁的介绍，或者对近期转会感兴趣，可以分几个层面来回答：先给出身份定位，再补充关键标签和重要事件，最后提一下最新动态。这样既能满足基础了解需求，也覆盖了时效信息。重点突出他是法国前锋、世界杯冠军、转会皇马这些标志性内容，避免过多细节让信息过载。'} response_metadata={'token_usage': {'completion_tokens': 451, 'prompt_tokens': 8, 'total_tokens': 459, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 112, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 8}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'df1c4540-6732-45bd-a67a-05f0c6a3223e', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f4a97-0bee-7c81-869e-5dd0a4a99574-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 451, 'total_tokens': 459, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 112}}

# %% [markdown]
# 按照完成顺序调用

# %%
##使用chat 1.x的方式
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os


load_dotenv(override=True)
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

model=init_chat_model(
    model="deepseek-v4-flash",  # 模型名称
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,  # DeepSeek API 的基础 URL
    

)

messages = [
    "梅西和c罗谁强",
    "阿根廷和法国队你觉得谁会获得2026世界杯冠军",
    "谁是姆巴佩",
]

responses = model.batch_as_completed(messages)

for response in responses:
    print(response)
# Out:
# (2, AIMessage(content='基利安·姆巴佩（Kylian Mbappé）是法国著名足球运动员，出生于1998年12月20日，司职前锋。他目前效力于西甲豪门皇家马德里，同时也是法国国家队的核心球员和队长。\n\n姆巴佩以惊人的速度、出色的盘带技术和门前终结能力闻名，被视为当今足坛最具影响力的球星之一。他的主要成就包括：\n\n- **俱乐部层面**：在摩纳哥出道并夺得法甲冠军，随后加盟巴黎圣日耳曼（PSG），帮助球队多次赢得法甲、法国杯等国内荣誉，并成为队史最佳射手。2024年夏季，他自由转会加盟皇家马德里。\n- **国家队层面**：2018年俄罗斯世界杯，19岁的姆巴佩打入4球（包括决赛进球），帮助法国队夺冠，并获评世界杯最佳新秀。2022年卡塔尔世界杯，他再次大放异彩，以8个进球荣膺金靴奖，并在决赛上演帽子戏法，但法国队最终获得亚军。\n- **个人荣誉**：多次获得法甲金靴、赛季最佳球员，并曾入选国际足联年度最佳阵容、欧足联年度最佳阵容等。\n\n姆巴佩被广泛视为梅西和C罗之后，未来金球奖和世界足球先生的有力竞争者。', additional_kwargs={'refusal': None, 'reasoning_content': '嗯，用户问的是“谁是姆巴佩”，这是一个关于足球运动员的简单知识性问题。需要给出清晰、准确的身份介绍。\n\n姆巴佩的全名是基利安·姆巴佩，法国籍，职业足球运动员。他是当前世界足坛最知名的前锋之一，以速度、爆发力和进球能力著称。关键信息点包括他的出生年份（1998年）、效力过的俱乐部（摩纳哥、巴黎圣日耳曼、皇家马德里）、国家队成就（2018年世界杯冠军）以及个人荣誉（世界杯金靴、法甲金靴等）。还需要提一下他目前效力的俱乐部（皇家马德里）。\n\n回答应该简洁，直接给出核心身份和主要成就，避免冗长。可以按时间顺序或重要性组织信息。'}, response_metadata={'token_usage': {'completion_tokens': 440, 'prompt_tokens': 8, 'total_tokens': 448, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 159, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 8}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '9eec0772-e807-4d84-b97f-c41ae990270e', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f4a99-0667-7762-bbb8-a3c97883359c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 440, 'total_tokens': 448, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 159}}))
# (0, AIMessage(content='这是一个足球界最经典、也最没有标准答案的话题。梅西和C罗都是划时代的超级巨星，他们的“强”体现在不同的维度。与其说谁更强，不如说他们定义了两种不同的巅峰。\n\n我们可以从几个关键角度来分析：\n\n### 1. 核心风格与技术特点：天赋与意志的对决\n\n-   **梅西（天赋的艺术大师）**：\n    -   **核心能力**：历史级的盘带、过人、视野和传球。他像一台不断进化的“足球处理器”，能在极小的空间内做出最合理、最致命的选择。\n    -   **风格**：依赖天赋、灵感和团队配合。他的比赛是“让足球说话”，通过无与伦比的球感、节奏变化和与生俱来的足球智商来撕开防线。他的**助攻和创造机会能力**也是历史顶级。\n    -   **弱点**：早期更依赖体系（如巅峰巴萨的传控），后期在阿根廷国家队经历了多年的质疑，直到赢得世界杯才彻底证明自己的领导力。\n\n-   **C罗（意志的完美模板）**：\n    -   **核心能力**：历史级的射门、无球跑动、头球、身体素质、爆发力和精神属性。他是一台不断升级的“进球机器”。\n    -   **风格**：依赖自律、努力和全面进化。他从一个花哨的边锋，通过极其严苛的训练，将自己改造成一个禁区内的全能终结者，能够适应不同的联赛和战术体系。\n    -   **弱点**：早期盘带相对花哨但效率不高，后期更依赖射门，盘带和助攻能力稍逊于梅西。\n\n**小结**：**梅西更像一个自然生长的足球精灵，C罗更像一个自我塑造的足球斗士。** 梅西强在“创造”，C罗强在“终结”。\n\n### 2. 核心荣誉与数据对比\n\n-   **金球奖（个人最高荣誉）**：梅西 8次，C罗 5次。梅西领先，这是个人荣誉的硬指标。\n-   **欧冠冠军（俱乐部最高荣誉）**：C罗 5次（曼联1，皇马4），梅西 4次（巴萨）。C罗在这项赛事上更具统治力。\n-   **国家队大赛**：梅西 1次世界杯冠军 + 2次美洲杯冠军 + 1次世界杯亚军；C罗 1次欧洲杯冠军 + 1次欧洲国家联赛冠军。**梅西赢得了足球世界的终极皇冠——世界杯**，这被认为是两人地位的分水岭。\n-   **国家队进球数**：C罗（130+）领先，但梅西（106+）也接近。\n-   **职业生涯总进球**：C罗（830+）领先，梅西（800+）紧随其后。\n-   **职业助攻数**：梅西（350+）领先，C罗（250+）。梅西的助攻数是两人差距最大的数据之一。\n\n**小结**：**梅西在个人荣誉（金球）、世界杯和国家队荣誉上更有分量；C罗在欧冠和总进球数上略微领先。** 2022年世界杯冠军让梅西在“历史地位”的讨论中占据了绝对优势。\n\n### 3. 关键纪录与历史地位\n\n-   **梅西**：单赛季91球（历史纪录）、7次西甲最佳射手（皮奇奇奖）、最多金球奖（8次）、最多自然年进球（91球）、同时拥有世界杯冠军、欧冠冠军和金球奖的少数球员之一。\n-   **C罗**：欧冠历史最佳射手（140球）、欧冠历史最佳助攻手（42次）、欧冠单赛季进球纪录（17球）、国家队历史最佳射手（130+球）、第一位在英超、西甲、意甲都拿过最佳射手的球员。\n\n### 4. 球迷群体与情感认同\n\n-   **梅西的粉丝**：更推崇足球的艺术性、天赋和团队配合。他们欣赏梅西在密集防守中闲庭信步的过人，和那些不可思议的传球。\n-   **C罗的粉丝**：更推崇个人的奋斗、意志力和在关键时刻的领袖气质。他们欣赏C罗逆天改命的决绝，和那种“只要他想爆发就能进球”的强大气场。\n\n### 结论：没有输家，只有不同时代的传奇\n\n**如果你问“谁的历史地位更高”？** 在2022年世界杯后，**梅西**的呼声更高。因为世界杯冠军是足球运动员的终极目标，梅西在个人荣誉（8金球）和世界杯冠军的加持下，被更多媒体和名宿认为是“历史最佳（GOAT）”。\n\n**如果你问“谁更全面”？** **C罗**的优势在于他能在不同联赛（英超、西甲、意甲）都取得成功，且能适应不同的战术体系。他的统治力辐射更广。\n\n**如果你问“谁的巅峰更震撼”？** **梅西**的巅峰（2010-2013年）是足球史上最可怕的个人表演之一；而**C罗**的巅峰（2013-2018年）则是在皇马欧冠三连冠时期的完美演绎。\n\n**最终答案**：**他们两人都是历史上最强的之一，没有绝对的强弱。** 你喜欢哪种风格的足球，谁就更强。如果你喜欢极致的艺术和天才，梅西是你的神；如果你喜欢不屈的意志和自我突破，C罗是你的神。\n\n**一个更公平的说法**：**梅西是“上帝视角”的足球艺术家，C罗是“人类意志”的完美体现。他们共同定义了足球的黄金时代，我们很幸运能见证这一切。**', additional_kwargs={'refusal': None, 'reasoning_content': '嗯，用户问的是梅西和C罗谁更强，这是一个足球界非常经典且容易引发争论的话题。用户可能希望得到一个客观、全面的分析，而不是简单的站队。我需要避免主观偏好，从技术、荣誉、风格、成就等多个维度进行对比，并指出这种比较本身的复杂性和个人偏好因素。\n\n想到了可以从几个核心方面展开：首先指出两人都是历史顶尖，但风格迥异。然后对比他们的技术特点，梅西更偏向天赋、盘带和创造力，C罗更偏向身体、力量和射门能力。接着对比关键荣誉，如金球奖、欧冠、国家队大赛等。再讨论各自打破的重要纪录。最后需要说明，这种比较往往取决于粉丝看重的标准，是更欣赏足球艺术还是竞技精神，并给出一个平衡的结论：他们都是各自时代的传奇，没有绝对的强弱，只有风格的不同。\n\n回答时需要保持冷静、客观的语气，提供具体数据和事实，避免情绪化表述。最后可以得出结论，认为两人都是历史最佳之一，谁更强是个主观问题。'}, response_metadata={'token_usage': {'completion_tokens': 1383, 'prompt_tokens': 10, 'total_tokens': 1393, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 212, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 10}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '1641512d-e9ee-48ee-b2f4-2a7b65542c77', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f4a99-065f-73a2-8a6b-8cdf68453590-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 1383, 'total_tokens': 1393, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 212}}))
# (1, AIMessage(content='预测2026年世界杯冠军归属，就像在迷雾中射击一个快速移动的靶心——变数太多，但我们可以基于现有情况做一次理性的推演。\n\n**要给出一个直接答案，目前来看，法国队赢得2026年冠军的概率，在纸面上略高于阿根廷队。** 原因有三点，但每一个前提都建立在“正常发展”的假设上：\n\n### 为什么法国队几率稍高？\n\n1.  **更年轻的黄金一代核心**：\n    -   到2026年，梅西将年满39岁，即使他凭借超凡的球商和定位球能力依然能保持高水平输出，但其跑动、对抗和瞬间爆发力大概率会进一步下滑。阿根廷的体系极度依赖梅西作为“减压阀”和“最后一传”的创造力。\n    -   反观法国，姆巴佩届时27岁，正值巅峰。他身边还有科曼（30岁）、图拉姆（28岁）、卡马文加（23岁）、琼阿梅尼（26岁）等中生代和新生代力量。法国队的核心架构比阿根廷年轻3-5岁，体能储备和阵容深度优势明显。\n\n2.  **恐怖的阵容深度与人才储备**：\n    -   法国队的人才井喷现象仍在持续。除了锋线，他们中后场储备同样奢华：萨利巴、于帕梅卡诺、孔德、特奥等人正值当打之年，而如埃梅里、杜埃等更年轻的天才已经在冲击主力。即使出现主力伤病，法国队也能拿出欧洲顶级水平的替补。\n    -   阿根廷在梅西、迪马利亚（届时可能已退出）、奥塔门迪等功勋老化后，中后场的更新换代面临考验。虽然恩佐、麦卡利斯特、阿尔瓦雷斯处于黄金期，但中卫和边后卫位置上，还没有出现能完全比肩法国同位置顶级水平的绝对巨星。\n\n3.  **战术体系与大赛经验的平衡**：\n    -   法国队拥有两种高效赢球模式：一是依靠天才球员的个人天赋（如姆巴佩的闪电战）直接摧毁对手；二是凭借控制力极强的中后场，执行德尚式的高效防反。这种双重保险，尤其适应杯赛的偶然性。\n    -   阿根廷的极致团队精神和斯卡洛尼的战术设计令人敬畏，但该体系对核心球员（尤其是梅西）的依赖度依然很高。一旦梅西在淘汰赛阶段遭遇高强度贴身盯防或状态波动，球队的进攻发起可能遇到瓶颈。\n\n### 阿根廷的卫冕机会在哪里？\n\n尽管纸面实力略处下风，但阿根廷卫冕的最大资本是**精神力与团队默契**。\n\n-   **冠军底蕴与心理韧性**：这支阿根廷队拥有历史上最坚韧的精神属性。2022年决赛点球大战击败法国，证明了他们能承受极限压力。这种“永不倒下”的气质在杯赛中往往能创造奇迹。\n-   **战术纪律的极致化**：只要梅西留在队中，斯卡洛尼就能围绕他构建一套严密的攻防战术：全员防守、快速转换、定位球战术。这套系统曾击败过所有强敌。\n-   **美洲杯的延续性**：如果阿根廷能在2024年美洲杯上成功卫冕，他们将带着“顶级冠军球队的惯性”进入2026年，信心和默契会达到顶峰。\n\n### 关键变量（谁也无法预知的“X因素”）\n\n1.  **梅西的选择**：他是否在2026年保持国家队生涯？若他不参赛，阿根廷夺冠概率将断崖式下降。\n2.  **主教练更迭**：斯卡洛尼在2024年一度传出可能离任，而德尚是否继续执教也对法国影响巨大。\n3.  **伤病与赛程**：美加墨世界杯因气候和长途飞行，对球员体能挑战极大。谁的核心阵容更少受伤，谁就占先机。\n4.  **抽签与对手**：如果法国和某支状态爆棚的非典型强队（如西班牙、巴西或东道主美国）过早相遇，也可能改变格局。\n\n### 结论\n\n**从竞技逻辑和人才厚度看，法国队是目前最接近“确定性”的夺冠热门。** 但阿根廷作为卫冕冠军，拥有强大的精神属性和战术凝聚力，绝不是没有机会。\n\n**我的个人倾向是：法国队60%概率夺冠，阿根廷40%概率卫冕。** 但足球之所以迷人，恰恰在于那40%里可能藏着最动人的故事——比如39岁的梅西，在北美大陆最后一次起舞，捧起一座永生难忘的奖杯。\n\n**你更愿意相信逻辑分析，还是相信一支球队创造奇迹的精神力量？**', additional_kwargs={'refusal': None, 'reasoning_content': '嗯，用户问的是2026年世界杯冠军预测，具体是阿根廷和法国队之间谁更有可能。这个问题看似简单，但涉及球队实力、阵容变化、战术风格、潜在伤病、抽签分组等多个动态因素，而且离2026年还有两年多，变数很大。直接说谁赢都不够严谨。\n\n用户可能是个球迷，想听听理性的分析，或者自己也在和朋友争论。深层需求不是要一个绝对答案，而是希望了解两队的优劣势对比，以及预测的合理依据。需要避免武断下结论，应该给出客观条件分析。\n\n首先想到2026年在美国、加拿大、墨西哥举办，赛制有变化，比赛密度和长途旅行对体能是考验。阿根廷是卫冕冠军，核心梅西届时39岁，状态未知，但球队年轻的洛塞尔索、恩佐、阿尔瓦雷斯等可能挑大梁。法国队实力储备恐怖，姆巴佩正值巅峰，格列兹曼还在，新一代如埃梅里、卡马文加成长迅速。教练德尚和斯卡洛尼都很稳。\n\n关键变量：梅西是否继续参赛，阿根廷的防守体系能否延续；法国队更衣室氛围，以及姆巴佩的领袖作用。目前看法国队阵容深度和年龄结构更优，但阿根廷的团队凝聚力和战术执行力惊人。\n\n直接说“法国队概率更大”比较稳妥，但得补充变数。还要提醒用户足球是圆的，意外太多。最后可以给出一个比较中肯的结论：从当下实力和未来两年潜力看，法国队稍占上风，但如果阿根廷能保持核心老将状态和新老交替顺利，仍有卫冕机会。'}, response_metadata={'token_usage': {'completion_tokens': 1336, 'prompt_tokens': 15, 'total_tokens': 1351, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 346, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 15}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'b9aa9b61-7b53-4599-afcd-8ac027f92d34', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f4a99-0662-7922-9b6c-4029f3a7a52a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 1336, 'total_tokens': 1351, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 346}}))

# %% [markdown]
# ## 3.profile

# %%
##使用chat 1.x的方式
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os
from rich import print as rprint


load_dotenv(override=True)
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

model=init_chat_model(
    model="deepseek-v4-flash",  # 模型名称
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,  # DeepSeek API 的基础 URL
    model_kwargs={
        "tools": [
    {
        "type": "function",
        "function": {
            "name": "get_weather",
            "description": "Get weather of a location, the user should supply a location first.",
            "parameters": {
                "type": "object",
                "properties": {
                    "location": {
                        "type": "string",
                        "description": "The city and state, e.g. San Francisco, CA",
                    }
                },
                "required": ["location"]
            },
        }
    },
]
    }  
)

response = model.invoke("帮我获取海口的天气")
rprint(response)
# Out:
# AIMessage(
#     content='好的，我来帮您查询海口的天气信息。',
#     additional_kwargs={
#         'refusal': None,
#         'reasoning_content':
# '用户想知道海口的天气。海口是海南省的省会，我需要提供城市和省份信息。让我调用天气工具。'
#     },
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 82,
#             'prompt_tokens': 302,
#             'total_tokens': 384,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 24,
#                 'rejected_prediction_tokens': None
#             },
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 256},
#             'prompt_cache_hit_tokens': 256,
#             'prompt_cache_miss_tokens': 46
#         },
#         'model_provider': 'deepseek',
#         'model_name': 'deepseek-v4-flash',
#         'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402',
#         'id': 'f4e96e46-9ffb-4d66-a9b3-4f9cc4bfd774',
#         'finish_reason': 'tool_calls',
#         'logprobs': None
#     },
#     id='lc_run--019f4ae6-507b-72b2-b3bc-7a40af94d763-0',
#     tool_calls=[
#         {
#             'name': 'get_weather',
#             'args': {'location': '海口, 海南'},
#             'id': 'call_00_B6OIkos1ffjZZGOYK0Yz4756',
#             'type': 'tool_call'
#         }
#     ],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 302,
#         'output_tokens': 82,
#         'total_tokens': 384,
#         'input_token_details': {'cache_read': 256},
#         'output_token_details': {'reasoning': 24}
#     }
# )

# %% [markdown]
# ## 4.model_kwargs

# %%
##使用chat 1.x的方式
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os


load_dotenv(override=True)
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

model=init_chat_model(
    model="deepseek-v4-flash",  # 模型名称
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL  # DeepSeek API 的基础 URL
)

print(model.profile)

# %% [markdown]
# ## 5.extra_body

# %%
##使用chat 1.x的方式

model=init_chat_model(
    model="deepseek:deepseek-v4-flash",  # 模型名称
    extra_body={
        "thinking": {"type": "enabled"}
    } 
)

rprint(model.invoke("如果我想要考公，我应该怎么做？"))
# Out:
# AIMessage(
#     content='想要顺利“上岸”公务员，需要的是**系统规划、信息筛选和持续执行力**。下面我为你梳理了一条从零开始的路径，
# 你可以根据自己的实际情况（是在校生、在职人员还是全职备考）进行调整。\n\n### 第一步：搞清楚“考什么”和“怎么考”\n\n1.
# **了解考试类型**：\n    -
# **国考**：中央机关及其直属机构招录，通常在每年11月底或12月初笔试。岗位级别高，竞争激烈。\n    -
# **省考/市考**：地方公务员招录，时间各省不同，很多省份参加“联考”（通常在3-4月）。岗位更贴近本地。\n    -
# **选调生**：专门针对优秀应届毕业生，门槛高（党员、学生干部、校级奖励等），但培养路径好，竞争相对小。\n\n2.
# **明确笔试科目**：\n    -
# **《行政职业能力测验》（行测）**：全是选择题。包含常识判断、言语理解、数量关系、判断推理、资料分析五大模块。**核心
# 是速度和准确率**，120分钟通常要做120-135道题。\n    -
# **《申论》**：全是主观题。根据材料回答问题，考察阅读理解、综合分析、提出和解决问题、文字表达能力。**核心是逻辑和层
# 次感**，很像写材料、写公文。\n\n3.
# **部分岗位加试**：公安岗位有《公安专业知识》和体能测试；外交部、商务部等可能会考口语或专业课。\n\n###
# 第二步：制定你的备考时间表（以6-9个月为例）\n\n**阶段一：信息搜集与心态准备（1-2周）**\n\n-
# **锁定信息源**：关注**国家公务员局官网**、所在省份的**人事考试网**。订阅 **“粉笔”**、**“华图”**、**“中公”**
# 等机构的公考公众号，获取职位表、大纲和报名时间。\n-
# **评估自身**：翻出一套近3年的真题（网上可免费下载），掐时间做一遍，不求对错，为了**感知难度、了解自己强项和弱项**。
# \n-
# **确定目标**：根据专业、户籍、学历、是否是应届生，在网上搜索往年职位表，找到自己能够报、愿意去的岗位（比如“某某市税
# 务局”、“某某区委办公室”），了解其进面分数。\n\n**阶段二：基础理论学习（2-3个月）**\n\n-
# **行测**：买一套系统教材（如粉笔980系统班）或找网课。按模块逐个突破，**先攻克“资料分析”和“判断推理”**，这是提分最快
# 的部分。然后是“言语理解”，最后是“数量关系”（可以适当放弃难题）和“常识判断”（靠积累）。每学完一个模块，立刻做专项练
# 习题巩固。\n-
# **申论**：切忌只看不写。跟一个老师的课（推荐李梦圆、张小龙、董盈辰等），学习如何“抄材料”和概括要点。**每周必须动手
# 写2-3道小题和1篇大作文**，写完对照答案修改。\n\n**阶段三：专项刷题与强化（2-3个月）**\n\n-
# **行测**：按模块刷题，比如“言语理解1000题”。**重点攻克错题**，整理错题本。开始练习**限时**做题，比如资料分析20分钟
# 做15题。\n-
# **申论**：开始刷历年真题。**先独立思考，写出答案，再比对多家机构的参考答案**，找出自己遗漏的点或表达不当的地方。学
# 习“政府思维”，比如看《人民日报》评论、学习强国APP的“要闻”板块，积累规范表述（如“放管服改革”、“基层治理现代化”）。\n
# \n**阶段四：全真模拟与冲刺（1-1.5个月）**\n\n-
# **行测**：每周至少2-3次**完全还原考场**的模拟考试（包括涂答题卡）。不断调整做题顺序，找到最适合自己的节奏（比如先做
# 资料分析，再做判断推理）。\n-
# **申论**：模拟时，严格按照字数要求，把字写清楚、工整。可以找上岸的学长学姐或报批改班，让别人批你的大作文，避免闭门
# 造车。\n-
# **心态**：这个阶段容易出现瓶颈（分数不涨），很正常。重点是**查漏补缺，放弃难题**，保证基础分和中等分稳拿。\n\n###
# 第三步：选岗与报名（决定成败的关键一步）\n\n**“考得好不如报得好”是公考铁律。**\n\n1.
# **筛选条件**：在职位表发布后，先用“专业”、“学历”、“学位”、“政治面貌”、“基层工作年限”、“应届/往届”等硬条件筛选，剩下
# 的岗位才是你的备选。\n2.
# **避开“三不限”**：如果专业实在冷门，被迫报“三不限”（不限专业、不限户籍、不限学历/基层经历）岗位，要做好百里挑一甚至
# 千里挑一的准备。\n3.
# **关注“报录比”**：报名期间，每天关注官网公布的报名人数。尽量选择**招2人以上、报录比相对较低**的岗位。通常招1人的岗
# 位比招多人的岗位风险大（哪怕报的人少，一旦遇到大神就是炮灰）。\n4.
# **慎重选择**：乡镇岗位可能5年服务期不能调动；异地、偏远地区岗位要评估自己是否能适应。**不要为了上岸而上岸**。\n\n##
# # 第四步：面试与政审（笔试通过后）\n\n-   **面试形式**：主要是**结构化面试**或**结构化小组面试**。\n-
# **准备方式**：笔试成绩出来后再准备可能来不及，建议笔试结束后就提前了解。面试练的是**表达逻辑和自信**。一定要**开口
# 说**，找人对练，或者报班（但别迷信保过班）。常用素材：社会热点分析、基层案例、个人成长经历。\n-
# **政审**：考察三龄两历、个人信用、直系亲属是否有违法犯罪记录等。确保自己平时言行合规，不要把政审当成走过场。\n\n###
# 最后，给你三个重要提醒：\n\n1.  **不要自我感动**：刷了1000道题如果全错等于零。**复盘比刷题本身更重要**。\n2.
# **不要相信“一个月上岸”**：那是极少数人（或岗位极冷）的故事。绝大多数人需要**持久战**，一次没上岸很正常，可以边工作
# 边考。\n3.
# **保持身体和心理**：每周留出半天彻底放松，运动、看电影都行。长期高压会效率爆炸。\n\n**现在你可以做的第一件事**：打
# 开手机应用商店，下载
# **“粉笔”APP**，先做一套2024年国考或省考的行测真题，**计时做一次**，看看自己的原始分是多少。\n\n公考是一场选拔性考试
# ，更是一场信息战和耐心战。祝你稳扎稳打，早日圆梦。',
#     additional_kwargs={
#         'refusal': None,
#         'reasoning_content':
# '嗯，用户问的是关于考公的准备方法。这个问题其实挺具体的，说明用户可能已经有了初步的打算，但不太清楚从何入手。考公是
# 一个系统工程，需要充分的时间准备和策略规划。\n\n首先需要帮用户明确两个关键点：一是用户现阶段是什么状态，是在校生还
# 是已经工作了？不同阶段备考策略差异很大。二是用户对考公的认知程度如何？是否清楚考试科目、时间节点、岗位选择这些基本
# 信息。不过用户没有提供这些信息，所以我需要在回答中覆盖各种可能的情况。\n\n考公的核心流程大致包括：了解考试类别（国
# 考、省考、选调生）、确定考试科目（行测和申论是公共科目，部分岗位加试专业知识）、制定备考计划、选择学习资料、刷题和
# 模考、报名选岗、笔试、面试、体检政审。我需要把这些拆解成可操作的步骤。\n\n第一步肯定是信息搜集。用户需要知道每年国
# 考一般在11月底笔试，省考一般在3-4月联考，部分省份单独命题。具体时间可以关注国家公务员局官网和各省人事考试网。同时要
# 了解报考条件，比如学历要求、专业限制、基层工作经历要求等。\n\n第二步是目标定位。用户需要结合自己的专业、学历、地域
# 偏好、发展意向来确定报考哪些岗位。有些岗位竞争非常激烈，比如中央部委、一线城市热门部门，报录比可能几百比一；而一些
# 基层岗位或者偏远地区岗位竞争相对小一些。用户可以查看往年职位表，筛选出自己符合条件的岗位，然后研究这些岗位的进面分
# 数线。\n\n第三步是制定备考计划。这是最核心的内容。行测主要分为常识判断、言语理解、数量关系、判断推理、资料分析五个
# 模块。申论主要考察阅读理解能力、综合分析能力、解决问题能力和文字表达能力。备考一般分为三个阶段：基础阶段（系统学习
# 知识点）、提高阶段（刷题训练，尤其是真题）、冲刺阶段（全真模拟，查漏补缺）。时间上来说，全职备考建议3-6个月，在职备
# 考可能需要6-12个月。\n\n第四步是选择备考资料。市场上主流的有粉笔、中公、华图等机构的教材和网课，还有近年真题卷。用
# 户需要根据自己的学习风格选择。建议先刷一套真题，了解自己的水平，再针对薄弱环节重点攻克。行测中资料分析和判断推理比
# 较容易提分，数量关系需要数学基础，常识和言语则靠平时积累。申论要多读多写，可以学习人民日报评论、半月谈等官方文章的
# 思路。\n\n第五步是报名策略。选岗非常关键，有句话叫“考得好不如报得好”。用户要关注报录比，避免扎堆；同时考虑岗位的发
# 展前景、工作强度、薪资待遇、是否有编制（公务员还是参公事业编）等因素。另外身份优势也很重要，比如应届生身份、党员、
# 基层工作经历、退役士兵等，这些都能帮助用户避开一些激烈竞争。\n\n第六步是备考执行。这部分需要自律和坚持。建议每天固
# 定时间学习，比如早上背时政和常识，上午刷行测，下午练申论，晚上复盘错题。使用番茄工作法等提高效率。行测要控制每题做
# 题时间，平均大概50秒一道题。申论要练习概括要点、分析问题、提出对策的能力，注意卷面整洁和字迹清晰。\n\n第七步是笔试
# 后的准备。如果笔试通过，需要准备面试。公务员面试主要是结构化面试或结构化小组面试，考察综合分析、组织协调、应急应变
# 、人际沟通、岗位认知等能力。建议提前练习，可以报班或者找人对练。同时要准备资格复审的材料，比如学历学位证书、身份证
# 明、报名登记表等。\n\n最后还要提醒用户一些容易被忽略的细节：比如体检标准（视力、血压等需符合要求）、政审要求（直系
# 亲属是否有违法记录）、岗位是否有服务期限制等。这些都会影响最终的录用。\n\n另外，用户的心态也很重要。考公竞争非常激
# 烈，很多热门岗位报录比甚至超过1000:1，需要做好多次备考的心理准备。可以给自己设定一个合理的时间周期，比如2年内考2-3
# 次，不要一次失败就放弃。\n\n综合来看，我需要给用户一个系统性的、分步骤的指南，同时指出关键注意事项和常见误区。回答
# 要实用、具体、鼓励但不盲目乐观。话题比较宏大，我会尽量突出重点，避免信息过载。现在可以组织语言回答用户了。'
#     },
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 2426,
#             'prompt_tokens': 12,
#             'total_tokens': 2438,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 933,
#                 'rejected_prediction_tokens': None
#             },
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0},
#             'prompt_cache_hit_tokens': 0,
#             'prompt_cache_miss_tokens': 12
#         },
#         'model_provider': 'deepseek',
#         'model_name': 'deepseek-v4-flash',
#         'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402',
#         'id': '39ebf3ea-b762-4dd8-af90-3d9a32dd8776',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
#     id='lc_run--019f4af2-7fcd-7b42-b7c6-c8a712d84da2-0',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 12,
#         'output_tokens': 2426,
#         'total_tokens': 2438,
#         'input_token_details': {'cache_read': 0},
#         'output_token_details': {'reasoning': 933}
#     }
# )

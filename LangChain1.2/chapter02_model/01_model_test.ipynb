# %%
##使用chat 1.x的方式
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os


load_dotenv(override=True)
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

llm_openai=init_chat_model(
    model="deepseek-v4-flash",  # 模型名称
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,  # DeepSeek API 的基础 URL
    temperature=0
)

for i in range(3):
    print(llm_openai.invoke("生成三首高考成功考到自己想去的学校的诗").content)
# Out:
# 收到你的请求，我为你准备了三种不同风格的诗作，分别对应从容、豪迈与青春热血三种心境，希望其中一首能恰好击中你当下的心情。
#
# ### 一、七律·金榜如愿
# **蟾宫桂影映寒窗，十载青灯伴墨香。**
# **笔底千言倾碧血，卷中万壑起沧浪。**
# **今朝喜跃龙门去，他日笑看沧海茫。**
# **莫问长安花几许，心舟已过万重江。**
#
# > **注释：** 这首诗以“蟾宫折桂”的古典意象开场，将十年寒窗的苦读比作青灯下的墨香。颔联用“千言”与“万壑”的壮阔，致敬你曾经的每一次全力以赴。尾联则以“心舟已过万重江”收束，意在告诉你：当你真正抵达梦想的彼岸时，回望来路，一切艰辛都已化作了云淡风轻的风景。
#
# ### 二、古风·少年行
# **少年负剑出乡关，志在青云日月边。**
# **墨海扬帆三万里，书山辟径九重天。**
# **春风得意马蹄疾，金榜题名展笑颜。**
# **从此长空任翱翔，不负韶华不负年。**
#
# > **注释：** 这一首风格更为豪迈奔放，适合满怀壮志的你。“负剑出乡关”与“志在青云”是对少年锐气的极致描绘。诗中“春风得意马蹄疾”化用孟郊的千古名句，但最终落脚于“不负韶华不负年”，既是对未来的期许，也是对自己青春时光最庄重的承诺。
#
# ### 三、现代诗·新的航向
# **晨曦**
# **在堆满试卷的书桌上**
# **悄然破茧**
# **将六月的汗水**
# **酿成金色的光**
#
# **这一次**
# **不是模拟的航线**
# **而是真正的远航**
# **你终于**
# **把梦想写成录取通知书上的**
# **第一行**
#
# > **注释：** 这首现代诗更贴近当下青少年的表达方式，用“破茧”和“金色曙光”的意象，将备考时光诗意化。它不谈“金榜题名”的沉重，而是将高考看作一次“真正的远航”，而你亲手将梦想写成了未来的序章——这是属于你自己的、充满仪式感的胜利。
#
# 希望这些诗能为你留下这一刻的光荣与梦想。如果未来你还需要记录更多生命的闪光时刻，我随时在这里。
# 《登科》
# 笔走龙蛇破万题，春风得意马蹄疾。
# 蟾宫折桂终如愿，金榜题名展笑眉。
#
# 《圆梦》
# 青灯黄卷伴晨昏，十载寒窗苦用心。
# 今日乘风登紫阙，心仪学府梦成真。
#
# 《赴考》
# 寒窗十载志凌云，考场挥毫笔有神。
# 榜上题名偿夙愿，春风送我入黉门。
# 以下是三首为高考成功考入理想学校而创作的诗词，分别以绝句、律诗和词的形式呈现，表达奋斗与喜悦之情：
#
# **其一·七绝·登科志**
# 十载寒窗磨剑锋，今朝笔落破长空。
# 春风得意马蹄疾，直上青云第一重。
#
# *解析：以“磨剑锋”喻长期苦读，“破长空”显考场气魄，后两句化用孟郊《登科后》诗意，贺成功之喜。*
#
# **其二·七律·蟾宫折桂**
# 墨海扬帆十二年，书山问道夜难眠。
# 千题淬炼锋如刃，万卷深研志比天。
# 笔下龙蛇腾锦绣，胸中星火化云烟。
# 今朝折桂蟾宫去，笑看春风满玉川。
#
# *解析：颔联以“千题”“万卷”具象化备考艰辛，颈联转写考场挥洒，尾联“蟾宫折桂”典故点题，“玉川”隐喻理想学府。*
#
# **其三·江城子·赴新程**
# 少年提笔破重城，越书峰，踏诗冰。
# 灯火三更，星月伴孤灯。
# 墨海千帆终探岸，风正举，露华凝。
#
# 明朝振翅向新庭，杏坛迎，玉阶明。
# 再续弦歌，万里纵才情。
# 莫问前程多远路，天宇阔，自鹏程。
#
# *解析：上阕回溯备考历程，“破重城”显突围之势；下阕展望未来，“杏坛”“玉阶”暗合校园，“鹏程”呼应庄子逍遥游之意境。*
#
# 每首作品皆以古典意象寄寓现代高考精神，既保留诗家词韵之雅致，又注入青春奋斗之热忱，愿学子们如诗中所颂：十年砺剑终成器，一日乘风上九霄。

# %% [markdown]
# 对比

# %%
##使用chat 1.x的方式
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os


load_dotenv(override=True)
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

llm_openai=init_chat_model(
    model="deepseek-v4-flash",  # 模型名称
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,  # DeepSeek API 的基础 URL
    temperature=1.9
)

for i in range(3):
    print(llm_openai.invoke("生成三首高考成功考到自己想去的学校的诗").content)
# Out:
# 这里有幸为您奉上三首风格各异的诗作，分别以“欣喜畅达”、“豪情壮志”和“回首感怀”为基调，祝贺您金榜题名，梦圆理想学府。
#
# ### 第一首：七言绝句·题名日
# **风格：** 轻快明亮，意象鲜明，侧重于考中后的喜悦与对未来的憧憬。
#
# **《及第日》**
#
# 曾似行舟浪里身，
# 孤灯照夜几千巡。
# 从今不羡锦鲤跃，
# 已化金鳞入玉津。
#
# *（注：诗中“锦鲤跃”借指跃龙门，“玉津”代指梦校所在的学术殿堂。）*
#
# ---
#
# ### 第二首：七言律诗·登科行
# **风格：** 典雅庄重，气势开阔，富有传统科举登科后的仪式感与自信。
#
# **《赴金陵有怀》**
#
# 十载寒窗意气收，一朝破茧出樊丘。
# 笔端已揽星河动，卷上应留日月浮。
# 桂子香时题雁塔，春风起处看吴钩。
# 从今跃过龙门浪，直取金陵最上楼。
#
# *（注：此诗用“金陵”代指理想中的大学名城，“雁塔题名”是古代科举进士的典故，表达功成名就。）*
#
# ---
#
# ### 第三首：现代诗·抵达
# **风格：** 意境优美，节奏舒缓，用温柔的笔触描绘梦想实现那一刻的内心感受。
#
# **《抵达一座理想的城》**
#
# 那个夏夜，我曾仰望星空，
# 将最遥远的那一颗，命名为“远方”。
# 十年，我用笔尖作桨，
# 在浩瀚题海无声地泅渡。
#
# 纸上的方寸，无数次垒起城墙，
# 又被梦想的星火，轻轻灼伤。
# 直到那天铃声响起，如释重负，
# 我看见，曾经许下的愿望，
# 悄然生长出翅膀。
#
# 原来，不是青春惊醒了太阳，
# 是沸腾的执着，终于抵达了那座向往的城。
# 站在这里，风中都是，
# 未来盛开的声音。
# 以下是三首关于高考成功考入理想学校的诗，内容积极向上，适合鼓励考生或表达喜悦之情：
#
# ---
#
# **其一·《题名日》**
# 寒窗十载墨痕深，破卷千轴星月沉。
# 笔底长风催战鼓，胸中浩气化鹏鲲。
# 今朝试刃锋芒露，他日攀云志气存。
# 待到春风传喜讯，笑折桂冠入此门。
#
# **其二·《致高考少年》**
# 青简堆中夜未央，孤灯照影战书窗。
# 千题磨砺龙泉剑，万卷熔成锦绣章。
# 笔下惊雷开雾霭，心间皓月引帆樯。
# 东风已渡云程近，他日龙门跨海长。
#
# **其三·《梦圆》**
# 挑灯曾伴月西斜，墨海行舟未有涯。
# 笔走龙蛇惊晓露，文成珠玉落星槎。
# 一朝破茧乘云起，万里乘风逐日遐。
# 旭日楼前传喜报，笑看学府绽新花。
#
# ---
#
# 希望这些诗能传递考场如愿的喜悦与力量！愿所有努力终得回响，金榜题名，奔赴心之所向。
# 《致高考少年》
# 十载寒窗砺剑锋，今朝考场试真功。
# 千题共研磨穿砚，万卷同参笔走龙。
# 墨海扬帆终破浪，书山辟径始登峰。
# 蟾宫折桂题名日，笑看春风满襟红。
#
# 《喜报》
# 捷报飞来喜欲狂，十年辛苦不寻常。
# 晨星未落披衣起，夜月西沉伏案忙。
# 题海无涯勤作棹，书山有路志为梁。
# 今朝遂得凌云愿，万里鹏程正启航。
#
# 《圆梦》
# 青衿十载守芸窗，今朝终得赴玉堂。
# 晨露沾衣寻典册，夜灯照壁写华章。
# 千题淬砺锋芒露，万卷深研智慧藏。
# 且看新程云起处，长风破浪正翱翔。

# %%
##使用chat 1.x的方式
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os


load_dotenv(override=True)
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

llm_openai=init_chat_model(
    model="deepseek-v4-flash",  # 模型名称
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,  # DeepSeek API 的基础 URL
    temperature=1.9
)

print(llm_openai.invoke("请为一款极致静音的机械键盘写3个充满诗意且极具张力的广告语").content)
# Out:
# 好的，为您构思了三款融合诗意与张力的极致静音机械键盘广告语：
#
# 1. **深海的寂静，指尖的史诗。**
#    （将极致的静音比作深海的静谧，而每一次击键则如同谱写波澜壮阔的史诗，动静之间张力十足。）
#
# 2. **敲击的不是键帽，是月光落地的低语。**
#    （用“月光落地的低语”这种极柔美、极难捕捉的意象，来具体化“静音”的境界，富有诗意与想象力。）
#
# 3. **当键盘学会沉默，让每一次敲击都像雪落无声。**
#    （“雪落无声”是好词，“键盘学会沉默”则用拟人化的手法赋予了产品生命与智慧，并形成了强烈的视听反差。）

# %%
##使用chat 1.x的方式
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os


load_dotenv(override=True)
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

llm_openai=init_chat_model(
    model="deepseek-v4-flash",  # 模型名称
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,  # DeepSeek API 的基础 URL
    max_tokens=10,
)

print(llm_openai.invoke("介绍你自己"))
# Out:
# content='' additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户让我介绍自己。这是一个非常基础'} response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 6, 'total_tokens': 16, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 10, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 6}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'f7704676-1be0-4f2a-9bca-755af45d1972', 'finish_reason': 'length', 'logprobs': None} id='lc_run--019f4a24-8451-7aa0-92c4-c0c3170619fe-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, 'output_tokens': 10, 'total_tokens': 16, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 10}}

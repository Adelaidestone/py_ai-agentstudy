# %%
import os
from dotenv import load_dotenv
from langchain_openai import OpenAIEmbeddings


load_dotenv(override=True)


# 注意：OpenAIEmbeddings 直接用时 model 不要带 "openai:" 前缀
# （只有 init_embeddings 才会解析 "provider:model" 格式并剥掉前缀）
embedding_model = OpenAIEmbeddings(
    model="text-embedding-v4",
    api_key=os.getenv("TONGYI_API_KEY"),
    base_url=os.getenv("TONGYI_BASE_URL"),
    check_embedding_ctx_length=False,
)

# %%
text = "你好，很高兴认识你"


embed_docs = embedding_model.embed_query(text)

print(len(embed_docs))

print(embed_docs[:5])
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[4], line 4
#       1 text = "你好，很高兴认识你"
#       2
#       3
# ----> 4 embed_docs = embedding_model1.embed_query(text)
#       5
#       6 print(len(embed_docs))
#       7
#
# File e:\MiniConda3\envs\langchain1.2\Lib\site-packages\langchain_openai\embeddings\base.py:801, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     791 """Call out to OpenAI's embedding endpoint for embedding query text.
#     792
#     793 Args:
#    (...)    798     Embedding for the text.
#     799 """
#     800 self._ensure_sync_client_available()
# --> 801 return self.embed_documents([text], **kwargs)[0]
#
# File e:\MiniConda3\envs\langchain1.2\Lib\site-packages\langchain_openai\embeddings\base.py:740, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     738 embeddings: list[list[float]] = []
#     739 for i in range(0, len(texts), chunk_size_):
# --> 740     response = self.client.create(
#     741         input=texts[i : i + chunk_size_], **client_kwargs
#     742     )
#     743     if not isinstance(response, dict):
#     744         response = response.model_dump()
#
# File e:\MiniConda3\envs\langchain1.2\Lib\site-packages\openai\resources\embeddings.py:136, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     130             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     131                 base64.b64decode(data), dtype="float32"
#     132             ).tolist()
#     134     return obj
# --> 136 return self._post(
#     137     "/embeddings",
#     138     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     139     options=make_request_options(
#     140         extra_headers=extra_headers,
#     141         extra_query=extra_query,
#     142         extra_body=extra_body,
#     143         timeout=timeout,
#     144         post_parser=parser,
#     145     ),
#     146     cast_to=CreateEmbeddingResponse,
#     147 )
#
# File e:\MiniConda3\envs\langchain1.2\Lib\site-packages\openai\_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File e:\MiniConda3\envs\langchain1.2\Lib\site-packages\openai\_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1067             err.response.read()
#    1069         log.debug("Re-raising status error")
# -> 1070         raise self._make_status_error_from_response(err.response) from None
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': 'The model `openai:text-embedding-v4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}, 'request_id': '942d702f-45cb-97b2-97a1-e16117afa50c'}

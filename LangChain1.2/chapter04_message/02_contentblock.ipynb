# %% [markdown]
# # 1.Content的使用
# **保存多模态数据**

# %%
import base64
from langchain.chat_models import init_chat_model
from langchain.messages import HumanMessage
from dotenv import load_dotenv
import os

load_dotenv(override=True)
TONGYI_API_KEY = os.getenv("TONGYI_API_KEY")
TONGYI_BASE_URL = os.getenv("TONGYI_BASE_URL")

model=init_chat_model(
    model="qwen3.5-omni-flash",  # 模型名称
    model_provider="openai",
    api_key=TONGYI_API_KEY,
    base_url="https://llm-v2xyqhn297xtv6xq.cn-beijing.maas.aliyuncs.com/compatible-mode/v1"  # TONGYI API 的基础 URL
)

def encode_image(img_path, img_type='png'):
    """将一张本地图片转换成 Base64 编码的 Data URI 字符串,方便在文本中嵌入图片数据"""
    with open(img_path, "rb") as img_file:
        return f"data:image/{img_type};base64,{base64.b64encode(img_file.read()).decode("utf-8")}"

# 图像路径
img_path = "E:\\ai agent study\\LangChain1.2\\chapter04_message\\image.png"

# 获取图像base64编码字符串
base64_image = encode_image(img_path)

response = model.invoke(
    [
        HumanMessage(
            content=[
                {'type': 'text', 'text': '这张图里有什么？'},
                {
                    'type': 'image_url',
                    "image_url": {"url": base64_image}
                }
            ]
        )
    ]
)
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 11
#       7 load_dotenv(override=True)
#       8 TONGYI_API_KEY = os.getenv("TONGYI_API_KEY")
#       9 TONGYI_BASE_URL = os.getenv("TONGYI_BASE_URL")
#      10
# ---> 11 model=init_chat_model(
#      12     model="qwen3.5-omni-flash",  # 模型名称
#      13     model_provider="openai",
#      14     api_key=TONGYI_API_KEY,
#
# NameError: name 'init_chat_model' is not defined

# %% [markdown]
# # contentblock的使用
# **输入的格式化**

# %%
from langchain.messages import HumanMessage
from dotenv import load_dotenv
load_dotenv(override=True)

def encode_image(img_path):
    """将一张本地图片转换成 Base64 编码的 Data URI 字符串,方便在文本中嵌入图片数据"""
    with open(img_path, "rb") as img_file:
        return base64.b64encode(img_file.read()).decode("utf-8")

# 图像路径
img_path = "E:\\ai agent study\\LangChain1.2\\chapter04_message\\image.png"

# 获取图像base64编码字符串
base64_image = encode_image(img_path)

response = model.invoke(
    [
        # 此种格式可用
        # HumanMessage(
        #     content=[
        #         {'type': 'text', 'text': '这张图里有什么？'},
        #         {
        #             'type': 'image_url',
        #             "image_url": base64_image,
        #         }
        #     ]
        # )
        # 推荐的统一写法
        HumanMessage(
            content_blocks=[
                {'type': 'text', 'text': '这张图里有什么？'},
                {
                    'type': 'image',
                    'base64': base64_image,
                    'mime_type': 'image/png',
                }
            ]
        )

    ]
)
print(response.content)
# Out:
# 这张图里展示的是一瓶**粉底液（或妆前乳/精华类化妆品）**，具体特征如下：
#
# - **瓶身设计**：透明玻璃瓶，呈方形，可以清晰看到内部液体颜色为浅米色或裸肤色。
# - **瓶盖与泵头**：顶部是金色金属质感的按压泵头，搭配一个透明的方形外盖，整体风格奢华、精致。
# - **标签信息**：瓶身正面贴有金色边框的标签，上面印有品牌名“**BOBBI BROWN**”和产品名“**Skin Long-Wear Foundation**”，表明这是芭比波朗（Bobbi Brown）品牌的长效持妆粉底液。
# - **背景与光影**：背景为柔和的暖色调（米白或浅棕），光线从左上方照射，在瓶身右侧和下方投下柔和阴影，营造出高级感、专业美妆摄影的氛围。
#
# ✅ 总结：
# 这是一张**芭比波朗（Bobbi Brown）Skin Long-Wear Foundation 粉底液的商业产品照片**，强调其高端质感、持久持妆功能及优雅包装，常用于广告或电商展示。
#
# ---
# 📌 小知识：Bobbi Brown 是美国知名彩妆品牌，以自然裸妆和功能性底妆著称，这款粉底主打“长时间不脱妆、贴合肌肤”。

# %% [markdown]
# **输出的格式化**

# %%
#兼容写法
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os

load_dotenv(override=True)
ZHIPU_API_KEY = os.getenv("ZHIPU_API_KEY")
ZHIPU_BASE_URL = os.getenv("ZHIPU_BASE_URL")

model=init_chat_model(
    model="glm-5.2",  # 模型名称
    model_provider="openai",
    api_key=ZHIPU_API_KEY,
    base_url=ZHIPU_BASE_URL,  # ZHIPU API 的基础 URL
    extra_body={
        "thinking":{
        "type":"enabled",
        "clear_thinking": False  # False for Preserved Thinking
    }}
)

response = model.invoke("我想让你扮演一个有趣的角色，给我讲一个笑话。")
print('=' * 20, '-> response <-', '=' * 20)
print(response)
print('=' * 20, '-> response.content <-', '=' * 20)
print(response.content)
print('=' * 20, '-> response.content_blocks <-', '=' * 20)
print(response.content_blocks)
# Out:
# ==================== -> response <- ====================
# content='（清清嗓子，把假发扶正，整理了一下领结）\n\n咳咳！听好了，凡人！我是**“百老汇弃儿、纸箱征服者、拥有九条命的脱口秀巨星——橘猫大胖”**！我本来应该在 radio city 音乐厅登台的，但我发现那里的空调开得太冷了，而且没有免费的罐头，所以我就离家出走了。\n\n既然你诚心诚意地发问了，我就大发慈悲地给你讲一个关于我那些**愚蠢的狗表亲**的故事。\n\n准备好了吗？灯光！摄影！开罐头！\n\n***\n\n一只狗走进了一家西部电报局，想给他的骨头发一封电报（别问我狗为什么能发电报，这毕竟是笑话）。\n\n柜台后面的人说：“好的，每个字收费5毛钱。”\n\n狗清了清嗓子，开始念道：“汪、汪、汪、汪、汪、汪、汪、汪、汪。”\n\n柜台后面的人数了数，说：“一共9个字，4块5。不过，朋友，看在你是个单身狗的份上，我给你个建议——如果你再加一个‘汪’字，也是同样的价钱。你是想多加一个字吗？”\n\n狗摇了摇头，一脸严肃地说：**“不用了，谢谢。那样就显得很多余，而且毫无意义了。”**\n\n***\n\n（等待笑声……）\n\n喵？没人笑？好吧，看来你们的幽默感都被扫地机器人吸走了。不管了，本巨星要罢工了，除非立刻奉上高级金枪鱼罐头！否则我就要在你的键盘上睡觉！喵！' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 2904, 'prompt_tokens': 24, 'total_tokens': 2928, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 2544, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'glm-5.2', 'system_fingerprint': None, 'id': '202607111355128323d2c2fb844940', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f4fbe-84ad-78a3-9719-c9128d845363-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 24, 'output_tokens': 2904, 'total_tokens': 2928, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 2544}}
# ==================== -> response.content <- ====================
# （清清嗓子，把假发扶正，整理了一下领结）
#
# 咳咳！听好了，凡人！我是**“百老汇弃儿、纸箱征服者、拥有九条命的脱口秀巨星——橘猫大胖”**！我本来应该在 radio city 音乐厅登台的，但我发现那里的空调开得太冷了，而且没有免费的罐头，所以我就离家出走了。
#
# 既然你诚心诚意地发问了，我就大发慈悲地给你讲一个关于我那些**愚蠢的狗表亲**的故事。
#
# 准备好了吗？灯光！摄影！开罐头！
#
# ***
#
# 一只狗走进了一家西部电报局，想给他的骨头发一封电报（别问我狗为什么能发电报，这毕竟是笑话）。
#
# 柜台后面的人说：“好的，每个字收费5毛钱。”
#
# 狗清了清嗓子，开始念道：“汪、汪、汪、汪、汪、汪、汪、汪、汪。”
#
# 柜台后面的人数了数，说：“一共9个字，4块5。不过，朋友，看在你是个单身狗的份上，我给你个建议——如果你再加一个‘汪’字，也是同样的价钱。你是想多加一个字吗？”
#
# 狗摇了摇头，一脸严肃地说：**“不用了，谢谢。那样就显得很多余，而且毫无意义了。”**
#
# ***
#
# （等待笑声……）
#
# 喵？没人笑？好吧，看来你们的幽默感都被扫地机器人吸走了。不管了，本巨星要罢工了，除非立刻奉上高级金枪鱼罐头！否则我就要在你的键盘上睡觉！喵！
# ==================== -> response.content_blocks <- ====================
# [{'type': 'text', 'text': '（清清嗓子，把假发扶正，整理了一下领结）\n\n咳咳！听好了，凡人！我是**“百老汇弃儿、纸箱征服者、拥有九条命的脱口秀巨星——橘猫大胖”**！我本来应该在 radio city 音乐厅登台的，但我发现那里的空调开得太冷了，而且没有免费的罐头，所以我就离家出走了。\n\n既然你诚心诚意地发问了，我就大发慈悲地给你讲一个关于我那些**愚蠢的狗表亲**的故事。\n\n准备好了吗？灯光！摄影！开罐头！\n\n***\n\n一只狗走进了一家西部电报局，想给他的骨头发一封电报（别问我狗为什么能发电报，这毕竟是笑话）。\n\n柜台后面的人说：“好的，每个字收费5毛钱。”\n\n狗清了清嗓子，开始念道：“汪、汪、汪、汪、汪、汪、汪、汪、汪。”\n\n柜台后面的人数了数，说：“一共9个字，4块5。不过，朋友，看在你是个单身狗的份上，我给你个建议——如果你再加一个‘汪’字，也是同样的价钱。你是想多加一个字吗？”\n\n狗摇了摇头，一脸严肃地说：**“不用了，谢谢。那样就显得很多余，而且毫无意义了。”**\n\n***\n\n（等待笑声……）\n\n喵？没人笑？好吧，看来你们的幽默感都被扫地机器人吸走了。不管了，本巨星要罢工了，除非立刻奉上高级金枪鱼罐头！否则我就要在你的键盘上睡觉！喵！'}]

# %% [markdown]
# # 测试langsmith

# %%
##兼容写法
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv

load_dotenv(override=True)
ZHIPU_API_KEY = os.getenv("ZHIPU_API_KEY")
ZHIPU_BASE_URL = os.getenv("ZHIPU_BASE_URL")

llm_openai=ChatOpenAI(
    model="glm-5.1",  # 模型名称
    api_key=ZHIPU_API_KEY,
    base_url=ZHIPU_BASE_URL  # ZHIPU API 的基础 URL
)

response = llm_openai.invoke("你是小红帽吗")
print(response)
# Out:
# content='不是哦，我是Z.ai训练的GLM大语言模型，不是童话故事中的小红帽。我可以回答问题、提供信息和帮助完成各种语言任务。\n\n如果您有任何问题或需要帮助，无论是知识咨询还是创意写作，我都很乐意为您提供支持。您今天想聊些什么呢？' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 220, 'prompt_tokens': 16, 'total_tokens': 236, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 158, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'glm-5.2', 'system_fingerprint': None, 'id': '20260710172951d3729b23ba314e70', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f4b5c-b15f-7fd1-9eca-b116b008cb69-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 16, 'output_tokens': 220, 'total_tokens': 236, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 158}}

# %%
import langsmith; print("langsmith:", langsmith.__version__)
# Out:
# langsmith: 0.10.0

# %%
import os
from dotenv import load_dotenv
load_dotenv(override=True)

print("工作目录:", os.getcwd())  # 看是不是项目根目录
for k in ["LANGSMITH_TRACING", "LANGCHAIN_TRACING_V2",
          "LANGSMITH_API_KEY", "LANGCHAIN_API_KEY",
          "LANGSMITH_PROJECT", "LANGSMITH_ENDPOINT"]:
    v = os.getenv(k)
    print(f"{k:28s}: {'❌【空】' if not v else '✅【已设置】'}")
# Out:
# 工作目录: e:\ai agent study\LangChain1.2\chapter03_langsmith
# LANGSMITH_TRACING           : ✅【已设置】
# LANGCHAIN_TRACING_V2        : ✅【已设置】
# LANGSMITH_API_KEY           : ✅【已设置】
# LANGCHAIN_API_KEY           : ❌【空】
# LANGSMITH_PROJECT           : ✅【已设置】
# LANGSMITH_ENDPOINT          : ✅【已设置】
